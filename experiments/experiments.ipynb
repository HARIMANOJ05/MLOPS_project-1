# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("C:\\Users\\Hari Manoj\\OneDrive\\Desktop\\datasets\\gemstone.csv")

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.value_counts()
# Out:
# id      carat  cut        color  clarity  depth  table  x     y     z     price
# 0       1.52   Premium    F      VS2      62.2   58.0   7.27  7.33  4.55  13619    1
# 129053  1.50   Very Good  G      VS2      63.2   59.0   7.20  7.27  4.57  12787    1
# 129044  0.71   Ideal      E      SI1      61.3   57.0   5.74  5.77  3.52  2329     1
# 129045  0.40   Ideal      E      VS1      62.1   55.0   4.73  4.75  2.95  947      1
# 129046  0.70   Very Good  H      SI1      61.8   55.0   5.69  5.66  3.50  2060     1
#                                                                                   ..
# 64526   1.51   Very Good  E      SI1      59.7   58.0   7.42  7.49  4.44  12539    1
# 64527   0.71   Premium    E      SI1      62.7   60.0   5.65  5.62  3.54  2631     1
# 64528   0.52   Ideal      I      VS1      61.6   56.0   5.16  5.18  3.19  1401     1
# 64529   0.34   Ideal      G      VS2      61.5   57.0   4.48  4.45  2.75  765      1
# 193572  0.71   Good       E      SI2      60.8   64.0   5.73  5.71  3.48  2258     1
# Name: count, Length: 193573, dtype: int64

# %%
data["carat"].value_counts()
# Out:
# carat
# 0.30    10758
# 1.01    10103
# 0.31     9538
# 0.70     7958
# 0.32     7548
#         ...
# 2.72        1
# 3.40        1
# 3.50        1
# 2.71        1
# 1.96        1
# Name: count, Length: 248, dtype: int64

# %%
data["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (193573, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
#data.drop(labels=['id'], axis=1,inplace=True)

# %%
#data.head()

# %%
#data.duplicated().sum()

# %%
#data['clarity'].values

# %%
#catogerical_data=data.columns[data.dtypes=="object"]

# %%
#numerical_data=data.columns[data.dtypes!="object"]

# %%
#data[catogerical_data].head()

# %%
#data[numerical_data].head()

# %%
#for col in catogerical_data:
    #print(data[col].value_counts())
    #print(f"count is {len(data[col].value_counts())}")
    #print("--------------------------------------")

# %%
#data[numerical_data].describe()

# %%
#plt.figure(figsize=(5,5))
#plt.show()


#for col in numerical_data:
    #sns.histplot(data=data,x=col,kde=True)
    #print("\n")
    #plt.show()

# %%
data
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 0            0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33
# 1            1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12
# 2            2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73
# 3            3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41
# 4            4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61
# ...        ...    ...        ...   ...     ...    ...    ...   ...   ...
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 0       4.55  13619
# 1       5.05  13387
# 2       3.50   2772
# 3       2.71    666
# 4       4.77  14453
# ...      ...    ...
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258
#
# [193573 rows x 11 columns]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
X=data.drop(labels=["id",'price'],axis=1)

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
y=data["price"]

# %%
y
# Out:
# 0         13619
# 1         13387
# 2          2772
# 3           666
# 4         14453
#           ...
# 193568     1130
# 193569     2874
# 193570     3036
# 193571      681
# 193572     2258
# Name: price, Length: 193573, dtype: int64

# %%
cat_cols=X.select_dtypes(include='object').columns

# %%
num_cols=X.select_dtypes(exclude='object').columns

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
X['color'].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
cut_categories=["Fair","Good","Very Good","Premium","Ideal"]
color_categories=["D" ,"E" ,"F" , "G" ,"H" , "I", "J"]
clarity_categories=["I1","SI2" ,"SI1" ,"VS2", "VS1" , "VVS2", "VVS1" ,"IF"]

# %%
cat_pipeline =Pipeline(

    steps=[

        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("encoding",OrdinalEncoder(categories=[cut_categories,color_categories,clarity_categories]))

    ]
)

# %%
num_pipeline= Pipeline(

    steps=[
        ("imputer",SimpleImputer()),
        ("scaler",StandardScaler())
        

    ]

)

# %%
preprocessor=ColumnTransformer(

    [
        ("num_pipe",num_pipeline,num_cols),
        ("cat_pipe",cat_pipeline,cat_cols)
    ]
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
num_cols
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
cat_cols
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[ 2.62606128, -2.88812879,  0.40086761, ...,  3.        ,
#          5.        ,  1.        ],
#        [-0.84529098,  0.164716  ,  0.92245845, ...,  3.        ,
#          1.        ,  2.        ],
#        [-0.84529098, -1.50047207,  1.96564013, ...,  3.        ,
#          2.        ,  2.        ],
#        ...,
#        [ 0.92272694,  0.90479959,  0.40086761, ...,  3.        ,
#          3.        ,  3.        ],
#        [-1.03934172, -0.66787803, -0.64231407, ...,  2.        ,
#          3.        ,  6.        ],
#        [-1.03934172, -0.02030489,  0.92245845, ...,  2.        ,
#          3.        ,  1.        ]])

# %%
preprocessor.transform(X_test)
# Out:
# array([[-0.62967904,  0.25722645, -0.12072323, ...,  4.        ,
#          0.        ,  2.        ],
#        [ 2.60450008, -2.1480452 , -0.12072323, ...,  2.        ,
#          3.        ,  1.        ],
#        [-1.1255865 , -1.22294072,  0.92245845, ...,  3.        ,
#          1.        ,  6.        ],
#        ...,
#        [-0.50031187, -0.48285713,  0.92245845, ...,  3.        ,
#          1.        ,  3.        ],
#        [-0.13377157,  0.44224735,  0.92245845, ...,  2.        ,
#          5.        ,  1.        ],
#        [ 0.51306425, -1.50047207, -0.64231407, ...,  4.        ,
#          1.        ,  1.        ]])

# %%
preprocessor.get_feature_names_out()
# Out:
# array(['num_pipe__carat', 'num_pipe__depth', 'num_pipe__table',
#        'num_pipe__x', 'num_pipe__y', 'num_pipe__z', 'cat_pipe__cut',
#        'cat_pipe__color', 'cat_pipe__clarity'], dtype=object)

# %%
X_train=pd.DataFrame(preprocessor.fit_transform(X_train),columns=preprocessor.get_feature_names_out())
X_test=pd.DataFrame(preprocessor.transform(X_test),columns=preprocessor.get_feature_names_out())

# %%
y_train
# Out:
# 47047     16075
# 37559       904
# 96522      1016
# 151589     1173
# 98360     11655
#           ...
# 119879     1410
# 103694    15064
# 131932     7209
# 146867      816
# 121958      408
# Name: price, Length: 129693, dtype: int64

# %%
from sklearn.linear_model import Lasso,LinearRegression,Ridge
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from xgboost import XGBRFRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
models={

    "lasso":Lasso(),
    "Ridge":Ridge(),
    "linear_regression":LinearRegression(),
    "xgboost":XGBRFRegressor(),
    "randomforest": RandomForestRegressor()


}

# %%
models.keys()
# Out:
# dict_keys(['lasso', 'Ridge', 'linear_regression', 'xgboost', 'randomforest'])

# %%
model_list=list(models.values())

# %%
model_list[1]
# Out:
# Ridge()

# %%
trained_model_list=[]
modelss_list=[]
r2_list=[]

# %%
def evaluate_model(true,pred):
    r2=r2_score(true,pred)
    mae=mean_absolute_error(true,pred)
    mse=mean_squared_error(true,pred)

    return mae, mse,r2

# %%
X
# Out:
#         carat        cut color clarity  depth  table     x     y     z
# 0        1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1        2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2        0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3        0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4        1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# ...       ...        ...   ...     ...    ...    ...   ...   ...   ...
# 193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39  2.67
# 193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77  3.47
# 193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75  3.62
# 193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49  2.81
# 193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71  3.48
#
# [193573 rows x 9 columns]

# %%
X_test.head()
# Out:
#    num_pipe__carat  num_pipe__depth  num_pipe__table  num_pipe__x  \
# 0        -0.629679         0.257226        -0.120723    -0.601058
# 1         2.604500        -2.148045        -0.120723     2.125144
# 2        -1.125587        -1.222941         0.922458    -1.374832
# 3        -1.017781        -0.575368         0.922458    -1.158895
# 4         0.858043         0.627268        -0.642314     0.946489
#
#    num_pipe__y  num_pipe__z  cat_pipe__cut  cat_pipe__color  cat_pipe__clarity
# 0    -0.582072    -0.572731            4.0              0.0                2.0
# 1     2.197955     1.957782            2.0              3.0                1.0
# 2    -1.415174    -1.469255            3.0              1.0                6.0
# 3    -1.161621    -1.194514            3.0              5.0                6.0
# 4     0.984523     1.003417            4.0              4.0                2.0

# %%
for i in range(len(list(models))):
    model=list(models.values())[i]
    
    model.fit(X_train,y_train)

    #make_prediction
   
    
    y_pred=model.predict(X_test)

    #this is for the validaiton
    MAE,MSE,R2=evaluate_model(y_test,y_pred)


    print("model training performance",model)
    print("MSE:", MSE)
    print("MAE:",MAE)
    print("R2 SCORE:",R2)

    r2_list.append(R2)

    print("="*40)
    print("\n")
# Out:
# model training performance Lasso()
# MSE: 1028877.431713885
# MAE: 676.0356586934795
# R2 SCORE: 0.9363817005922814
# ========================================
#
#
# model training performance Ridge()
# MSE: 1028762.3138157587
# MAE: 674.7697161746399
# R2 SCORE: 0.9363888186460791
# ========================================
#
#
# model training performance LinearRegression()
# MSE: 1028753.639827506
# MAE: 674.7352796098319
# R2 SCORE: 0.9363893549824441
# ========================================
#
#
# model training performance XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, reg_alpha=None, ...)
# MSE: 504446.0998139675
# MAE: 398.0510988315494
# R2 SCORE: 0.9688087105751038
# ========================================
#
#
# model training performance RandomForestRegressor()
# MSE: 374870.9160727966
# MAE: 310.4291346919695
# R2 SCORE: 0.9768207082370947
# ========================================

# %%
max(r2_list)
# Out:
# 0.9768207082370947
